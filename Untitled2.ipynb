# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e24fa76-9a86-4827-92a1-e92b245efeb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e24fa76-9a86-4827-92a1-e92b245efeb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv

# %%
import io
wine = pd.read_csv(io.BytesIO(uploaded['winequality-red.csv']), sep=";")

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df = pd.DataFrame(wine)

# %%
df.head(50)
# Out:
#     fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0             7.4             0.700         0.00  ...       0.56      9.4        5
# 1             7.8             0.880         0.00  ...       0.68      9.8        5
# 2             7.8             0.760         0.04  ...       0.65      9.8        5
# 3            11.2             0.280         0.56  ...       0.58      9.8        6
# 4             7.4             0.700         0.00  ...       0.56      9.4        5
# 5             7.4             0.660         0.00  ...       0.56      9.4        5
# 6             7.9             0.600         0.06  ...       0.46      9.4        5
# 7             7.3             0.650         0.00  ...       0.47     10.0        7
# 8             7.8             0.580         0.02  ...       0.57      9.5        7
# 9             7.5             0.500         0.36  ...       0.80     10.5        5
# ...

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0             False             False        False  ...      False    False    False
# 1             False             False        False  ...      False    False    False
# 2             False             False        False  ...      False    False    False
# 3             False             False        False  ...      False    False    False
# 4             False             False        False  ...      False    False    False
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594          False             False        False  ...      False    False    False
# 1595          False             False        False  ...      False    False    False
# 1596          False             False        False  ...      False    False    False
# 1597          False             False        False  ...      False    False    False
# ...

# %%
len(df.index)-df.count()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
length = len(df.index)
print(length)
# Out:
# 1599

# %%
df1 = df[df.quality == 5]

# %%
len(df1.index)
# Out:
# 681

# %%
df2 = df[df.quality == 6]
df2.head
# Out:
# <bound method NDFrame.head of       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 19              7.9             0.320         0.51  ...       1.08      9.2        6
# 20              8.9             0.220         0.48  ...       0.53      9.4        6
# 24              6.9             0.400         0.14  ...       0.63      9.7        6
# 29              7.8             0.645         0.00  ...       0.59      9.8        6
# ...             ...               ...          ...  ...        ...      ...      ...
# 1592            6.3             0.510         0.13  ...       0.75     11.0        6
# 1593            6.8             0.620         0.08  ...       0.82      9.5        6
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# ...

# %%
len(df2.index)
# Out:
# 638

# %%
(638+681)/1599*100
# Out:
# 82.48905565978737

# %%
df['pH'].max()-df['pH'].min()
# Out:
# 1.2699999999999996

# %%
 x = df2[df2.sulphates > 0.65]

# %%
len(x.index)
# Out:
# 289

# %%
x.head()
# Out:
#     fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 19            7.9             0.320         0.51  ...       1.08      9.2        6
# 42            7.5             0.490         0.20  ...       0.90     10.5        6
# 69            8.0             0.705         0.05  ...       0.95     10.5        6
# 84            6.3             0.300         0.48  ...       0.78     10.3        6
# 86            8.6             0.490         0.28  ...       1.95      9.9        6
#
# [5 rows x 12 columns]

# %%
x.std()
# Out:
# fixed acidity            1.975578
# volatile acidity         0.146697
# citric acid              0.193206
# residual sugar           1.488675
# chlorides                0.050384
# free sulfur dioxide     10.861822
# total sulfur dioxide    22.476676
# density                  0.002034
# pH                       0.159156
# sulphates                0.160278
# alcohol                  1.044454
# quality                  0.000000
# dtype: float64

# %%
df2.var()
# Out:
# fixed acidity             3.232260
# volatile acidity          0.025909
# citric acid               0.038067
# residual sugar            2.078141
# chlorides                 0.001565
# free sulfur dioxide      98.821718
# total sulfur dioxide    626.913975
# density                   0.000004
# pH                        0.023714
# sulphates                 0.025170
# alcohol                   1.101742
# quality                   0.000000
# dtype: float64

# %%
dfx = df[df.quality > 6 ]

# %%
dfx.head(60) # dataframe with wine samples with quality greater than 6
# Out:
#      fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 7              7.3             0.650         0.00  ...       0.47     10.0        7
# 8              7.8             0.580         0.02  ...       0.57      9.5        7
# 16             8.5             0.280         0.56  ...       0.75     10.5        7
# 37             8.1             0.380         0.28  ...       0.73      9.7        7
# 62             7.5             0.520         0.16  ...       0.62      9.5        7
# 128            8.0             0.590         0.16  ...       0.92     10.5        7
# 198            5.4             0.835         0.08  ...       0.85     13.0        7
# 200            9.6             0.320         0.47  ...       0.82     10.3        7
# 205           12.8             0.300         0.74  ...       0.77     10.8        7
# 206           12.8             0.300         0.74  ...       0.77     10.8        7
# ...

# %%
len(dfx.index)
# Out:
# 217

# %%
 x = dfx[dfx.sulphates > 0.65]

# %%
alpha = df.loc[df['quality'] > 6]
len(alpha.index)
# Out:
# 217

# %%
y = alpha[alpha.sulphates > 0.65]

# %%
alpha.head()
# Out:
#     fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 7             7.3              0.65         0.00  ...       0.47     10.0        7
# 8             7.8              0.58         0.02  ...       0.57      9.5        7
# 16            8.5              0.28         0.56  ...       0.75     10.5        7
# 37            8.1              0.38         0.28  ...       0.73      9.7        7
# 62            7.5              0.52         0.16  ...       0.62      9.5        7
#
# [5 rows x 12 columns]

# %%
len(y.index)
# Out:
# 161

# %%
alpha.std()
# Out:
# fixed acidity            1.999977
# volatile acidity         0.144963
# citric acid              0.194438
# residual sugar           1.363026
# chlorides                0.028480
# free sulfur dioxide     10.234615
# total sulfur dioxide    32.572238
# density                  0.002201
# pH                       0.154478
# sulphates                0.134038
# alcohol                  0.998153
# quality                  0.276443
# dtype: float64

# %%
alpha.var
# Out:
# <bound method DataFrame.var of       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 7               7.3              0.65         0.00  ...       0.47    10.00        7
# 8               7.8              0.58         0.02  ...       0.57     9.50        7
# 16              8.5              0.28         0.56  ...       0.75    10.50        7
# 37              8.1              0.38         0.28  ...       0.73     9.70        7
# 62              7.5              0.52         0.16  ...       0.62     9.50        7
# ...             ...               ...          ...  ...        ...      ...      ...
# 1541            7.4              0.25         0.29  ...       0.76    10.90        7
# 1544            8.4              0.37         0.43  ...       0.81    11.20        7
# 1549            7.4              0.36         0.30  ...       0.70    11.40        8
# 1555            7.0              0.56         0.17  ...       0.68    10.55        7
# ...

# %%
x = df[df.pH == df.pH.max()]
x
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 1316            5.4              0.74          0.0  ...       0.59     12.5        6
# 1321            5.0              0.74          0.0  ...       0.59     12.5        6
#
# [2 rows x 12 columns]

# %%
y = df[df.pH == df.pH.min()]
y
# Out:
#      fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 151            9.2              0.52          1.0  ...        2.0      9.4        4
#
# [1 rows x 12 columns]

# %%
dfy = df[df.quality ==5 ]

# %%
len(dfy.index)
# Out:
# 681
